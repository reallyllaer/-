# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
DATA_PATH = '/content/drive/MyDrive/2조_누구냐, 넌!/04. 기타자료/Naver_shopping_크롤링/Modeling/한수길/data/'

# %%
df_1 = pd.read_csv(f"{DATA_PATH}가격최종labeling_완료.csv")
df_2 = pd.read_csv(f"{DATA_PATH}세정력최종labeling_완료.csv")
df_3 = pd.read_csv(f"{DATA_PATH}향기최종labeling_완료.csv")
df_4 = pd.read_csv(f"{DATA_PATH}트러블최종labeling_완료.csv")
df_5 = pd.read_csv(f"{DATA_PATH}배송최종labeling_완료.csv")
df_6 = pd.read_csv(f"{DATA_PATH}탈모효과최종labeling_완료.csv")
df_7 = pd.read_csv(f"{DATA_PATH}머릿결최종labeling_완료.csv")

# %%
tmp2 = df_2['세정력/거품']
tmp3 = df_3['향기']
tmp4 = df_4['트러블/진정']
tmp5 = df_5['배송/서비스/고객대응']
tmp6 = df_6['탈모 효과 및 쿨링감']
tmp7 = df_7['머릿결*']

# %%
df_1['세정력/거품'] = tmp2
df_1['향기'] = tmp3
df_1['트러블/진정'] = tmp4
df_1['배송/서비스/고객대응'] = tmp5
df_1['탈모 효과 및 쿨링감'] = tmp6
df_1['머릿결*'] = tmp7

# %%
df_1
# Out:
#                                                  content  score       date  \
# 0                                             만반잔당갈살살칸캉차      1  21.10.09.
# 1                             펌프가 부러졌어요...이거 빼면 정말 좋은데..      1  21.08.16.
# 2                                             똑같네 똑같아 ㅡㅡ      1  20.10.19.
# 3      좋다고 해서 샀는데... 좋은지도 나쁜지도 모르겠어요~ 아모레는 동물실험을 필요에 ...      1  20.06.14.
# 4                                        평이 좋아서 샀는데 안맞네요      2  23.08.12.
# ...                                                  ...    ...        ...
# 84779                                        아들이 잘 쓰고있어요      5  21.09.18.
# 84780                                         써볼께요ㅎㅎ써볼께요      5  21.09.18.
# 84781                               맛있고 배송도 빠르고 넘 넘 좋아요~      5  21.09.17.
# 84782                                        역시 닥터그루트닙니당      5  21.09.17.
# 84783                                      떡 잘지는 머리에 좋아요      5  21.09.16.
#
# ...

# %%
df_1.to_csv(f"{DATA_PATH}labeling최종완료.csv", index=False, encoding='utf-8-sig')

# %%
df_real = pd.read_csv(f"{DATA_PATH}real_labeling_emotion.csv")

# %%
df_1 = df_1.iloc[:,:11]

# %%
df_1
# Out:
#                                                  content  score       date  \
# 0                                             만반잔당갈살살칸캉차      1  21.10.09.
# 1                             펌프가 부러졌어요...이거 빼면 정말 좋은데..      1  21.08.16.
# 2                                             똑같네 똑같아 ㅡㅡ      1  20.10.19.
# 3      좋다고 해서 샀는데... 좋은지도 나쁜지도 모르겠어요~ 아모레는 동물실험을 필요에 ...      1  20.06.14.
# 4                                        평이 좋아서 샀는데 안맞네요      2  23.08.12.
# ...                                                  ...    ...        ...
# 84779                                        아들이 잘 쓰고있어요      5  21.09.18.
# 84780                                         써볼께요ㅎㅎ써볼께요      5  21.09.18.
# 84781                               맛있고 배송도 빠르고 넘 넘 좋아요~      5  21.09.17.
# 84782                                        역시 닥터그루트닙니당      5  21.09.17.
# 84783                                      떡 잘지는 머리에 좋아요      5  21.09.16.
#
#        brand  가격  세정력/거품  향기  트러블/진정  배송/서비스/고객대응  탈모 효과 및 쿨링감  머릿결*
# ...

# %%
df_real
# Out:
#                                                 content  score       date  \
# 0     배송누락되어 본사확신다고 하시고 다시 주문번호 올려달라고 하시니 대응절차가 문제있어...      1  23.08.31.
# 1                                시원하고 좋은데 뾰루지 많이나고 따갑네요      1  23.09.07.
# 2                                  전에 쓰던 샴푸보다 머리카락 더빠짐…      1  23.03.25.
# 3                 저랑은 안맞네요 계속 쓰다보니 두피 너무 가렵고 비듬각질이 생기네요      1  23.02.18.
# 4                                         효과는없고 계속많이빠져요      1  22.07.27.
# ...                                                 ...    ...        ...
# 5915                         머릿결이 좀 좋아졌어요 거품도 잘 나서 만족해요      5  21.12.12.
# 5916  1. 머리 덜 간지러움 2. 각질 비듬 줄어듬 3. 머리카락이 두꺼워지는게 느껴짐 ...      5  21.12.12.
# 5917  지성두피라서 오후만 되면 앞머리 떡지던 사람으로서 이정도로 만족스러운 샴푸는 처음입...      5  21.12.01.
# 5918  얼굴은 건성 두피은 지성인 말잇못 타입인데 추천의 추천을 받아서 구입했어요. 참고로...      5  21.11.10.
# 5919  향기 좋구요. 머리 안 가렵구요. 탈모방지되는지는 잘 모르겠지만 사용하기에 괜찮은 ...      5  21.12.27.
#
#       brand  가격  세정력/거품   향기  트러블/진정  배송/서비스/고객대응  탈모 효과 및 쿨링감  머릿결*
# ...

# %%
type(df_real), type(df_1)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.frame.DataFrame)

# %%
df_last = pd.concat([df_real, df_1], axis=0).reset_index(drop=True)

# %%
df_last.to_csv(f"{DATA_PATH}최종통합본.csv", index=False, encoding='utf-8-sig')
